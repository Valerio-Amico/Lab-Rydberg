# %%
import numpy as np
import arc
import matplotlib.pyplot as plt

# %%
my_atom = arc.Rubidium87()
rs = np.linspace(0,0.00001,100)
U = [my_atom.corePotential(l=0,r=r) for r in rs]

# %%
plt.plot(rs,U)
plt.show()
