# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [
    (0,	1),
    (1,	1.015942028985507),
    (2,	1.005797101449275),
    (3,	0.9681159420289854),
    (4,	0.894927536231884),
    (5,	0.7666666666666666),
    (6,	0.6253623188405797),
    (7,	0.4746376811594203),
    (8,	0.341304347826087),
    (9,	0.2326086956521739),
    (10, 0.1626),
    (12, 0.0826),
    (14, 0.034),
    (16, 0.02),
    (20, 0.0068462),
]
datay = [data_[1] for data_ in data]
X = [80-data_[0] for data_ in data]

plt.plot(X, datay, "o")
plt.xlabel("radiofrequency (MHz)", fontsize=16)
plt.xticks(np.arange(60,81,step=5))

plt.ylabel("relative efficiency", fontsize=16)
plt.yscale("log")

plt.show()

# %%
10 * np.log10(0.1)
# Out:
# -10.0
